# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import plotly.plotly as py
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ## Import raw data

# %%
raw_data = pd.read_csv("Consumer_Coded_Comments_2017.csv", index_col=None)

# %%
#raw_data.columns

# %%
#raw_data.head(3)

# %% [markdown]
# ## TF-IDF based Vectorization

# %%
import nltk
import string
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.porter import PorterStemmer

token_dict = {}
stemmer = PorterStemmer()
Y = [] # Sensiment labels

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

for i in range(raw_data.shape[0]):
    record = raw_data.iloc[i]
    if not pd.isnull(record.Comment) and not pd.isnull(record.Sentiment):
        lowers = record.Comment.lower()

        no_punctuation = lowers.translate(None, string.punctuation)
        no_punctuation = unicode(no_punctuation, errors='replace')

        token_dict[i] = no_punctuation
        
        # the corresponding y
        Y.append(record.Sentiment)
## so far: token_dict is {index:cleaned comment, ...}, Y is the corresponding sentiment.

if not os.path.isfile('TF-IDF.csv'): 
    #this can take some time
    tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(1,1))
    tfs = tfidf.fit_transform(token_dict.values())

    df = pd.DataFrame(data=tfs.toarray(), 
                  index = token_dict.keys(), 
                  columns=tfidf.get_feature_names())
    df.to_csv('TF-IDF.csv', encoding='utf-8')
else:
    df = pd.read_csv('TF-IDF.csv')    
    
df_sentiment = pd.DataFrame()
df_sentiment['sentiment'] = Y
df_sentiment.to_csv("Sentiments.csv")

# %%
from sklearn.model_selection import train_test_split
print "here"
all_X_array = df.as_matrix()
print "here too"
all_Y_array = Y
print "here three"
data = train_test_split(all_X_array, all_Y_array, test_size=0.2, random_state=10)
X_train, X_test, Y_train, Y_test = data
print X_train[0], X_test[0], Y_train[0], Y_test[0]
# Out:
# here
# here too
# here three
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier


def benchmark(clf, data):
    X_train, X_test, Y_train, Y_test = data
    print X_train[0], X_test[0], Y_train[0], Y_test[0]
    clf.fit(X_train, Y_train)
    pred = clf.predict(X_test)
    precision, recall, fbeta_score, support = metrics.precision_recall_fscore_support(
        Y_test, pred, average=None)
    print metrics.classification_report(Y_test, pred)



clf_knn = KNeighborsClassifier(n_neighbors=10)

clf_MLP = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(100, 5, 3, ), random_state=1)

clf_rf= RandomForestClassifier(
            n_estimators=100,
            max_depth=None,
            min_samples_split=2,
            random_state=0)

clf_lsvc = LinearSVC()
clf_dt = DecisionTreeClassifier(
            max_depth=None, min_samples_split=6, random_state=0)
clf_adaboost = AdaBoostClassifier(n_estimators=200)

X_train, X_test, Y_train, Y_test = data

print "Training data size:", len(Y_train)
print "Test data size:", len(Y_test)
labels = list(set(Y_test))
print "#of classes:", len(labels)

print('=' * 50)
print("Neural Network-MLP")
benchmark(clf_MLP, data)

print('=' * 50)
print("SVM")
benchmark(clf_lsvc, data)

print('=' * 50)
print("Decision Tree")
benchmark(clf_dt, data)

print('=' * 50)
print("Random Forest")
benchmark(clf_rf, data)

print('=' * 50)
print("AdaBoost")
benchmark(clf_adaboost, data)
# Out:
# Training data size: 18722
# Test data size: 4681
# #of classes: 3
# ==================================================
# Neural Network-MLP
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive
#              precision    recall  f1-score   support
#
#    Negative       0.93      1.00      0.96       902
#     Neutral       1.00      0.63      0.77       589
#    Positive       0.96      1.00      0.98      3190
#
# avg / total       0.96      0.95      0.95      4681
#
# ==================================================
# SVM
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive
#              precision    recall  f1-score   support
#
#    Negative       1.00      0.86      0.92       902
#     Neutral       0.15      1.00      0.26       589
#    Positive       0.00      0.00      0.00      3190
#
# avg / total       0.21      0.29      0.21      4681
#
# ==================================================
# Decision Tree
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive
#              precision    recall  f1-score   support
#
#    Negative       1.00      1.00      1.00       902
#     Neutral       1.00      1.00      1.00       589
#    Positive       1.00      1.00      1.00      3190
#
# avg / total       1.00      1.00      1.00      4681
#
# ==================================================
# Random Forest
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive
#              precision    recall  f1-score   support
#
#    Negative       0.97      0.99      0.98       902
#     Neutral       0.99      0.97      0.98       589
#    Positive       1.00      1.00      1.00      3190
#
# avg / total       0.99      0.99      0.99      4681
#
# ==================================================
# AdaBoost
# [17954.     0.     0. ...     0.     0.     0.] [12114.     0.     0. ...     0.     0.     0.] Positive Positive
#              precision    recall  f1-score   support
#
#    Negative       1.00      1.00      1.00       902
#     Neutral       1.00      1.00      1.00       589
#    Positive       1.00      1.00      1.00      3190
#
# avg / total       1.00      1.00      1.00      4681

# %%
import csv



def show_uncorrect(classifier, test_X, y_real, raw_data):
    y_predict = classifier.predict(test_X)
    writer = csv.writer(open("mislabel.csv", 'w'))
    for i in xrange(len(y_predict)):
        if y_predict[i] != y_real[i]:
            
            writer.writerow([y_real[i], y_predict[i], raw_data.iloc[i].Comment])
            print "{},{},{} \n".format(y_real[i], y_predict[i], raw_data.iloc[i].Comment)

mis_dict = show_uncorrect(clf_MLP, X_test, Y_test, raw_data)
# Out:
# Neutral,Positive,By what for now I didn't of virus problem, which is positive. Nevertheless, although I have a two year subscription, I have received several very incentives messages from McAfee to resubscribe me after a year only claiming that I didn't have any antivirus! Fortunately, I am not been fooled, otherwise, I would have paid a year for nothing.
#
# Neutral,Negative,because I renewed with you at the given time but you keep telling me I am no longer covered and you are too expensive.
#
# Neutral,Positive,I like the way you can use McAfee on several devices however I kept getting alerts saying I wasn't up to date but I was!  Which was frustrating.
#
# Neutral,Positive,I'm tired of all the McAfee pop-ups every time I open the internet, telling me my firewall is down.  I paid a hefty price for one year's coverage, and yet you keep trying to sell me more coverage. SERIOUSLY  looking at getting rid of this product, and company; I am looking for a replacement.
#
# Neutral,Positive,Bad customer support, good products being flagged as problematic.
#
# Neutral,Positive,Because mcafee keeps renewing & wont allow me access to my account to cancel
#
# Neutral,Positive,After having bought a Dell PC with pre-installed McAffe, I was surprised to find a charge on my credit card without any explanation or acceptance on my part. There's no way I would recommend the product to a company that deals so its 'customers'.
#
# Neutral,Positive,It is not possible to contact Sales and/or support of McAfee. I can not change my account. Product cancellation is not possible. Than but not pay more.
#
# Neutral,Positive,You refuse to answer e-mail you renewed my subscription when it wasn't due until 5-20-17 and charged my credit card when I can buy it for 5 units for $49.99 at local office store.
#
# Neutral,Positive,You took money from my account prior to warning me that you were about to do that, and then you never responded to my e-mails.
#
# Neutral,Positive,I no longer have the tablet for which I subscribed to MCAfee and for the last two years you have automatically taken money from my card. You should ask permission before taking money out of cards. How am I going to be refunded?
#
# Neutral,Positive,the auto renewel that took payment without warning me first - only received an email *after* the product was auto renewed, when I had completely forgotten I had the product on auto renewal - in fact, I hadn't even downloaded the product in 3 years, so I had clearly forgotten all about it all together -
#
# Neutral,Positive,mcafree renewed without me wanting it renewed
#
# Neutral,Positive,you did not get my approval to renew
#
# Neutral,Negative,I DID NOT WANT IT AUTOMATICALLY RENEWED BUT THE MONEY WAS TAKEN OUT BEFORE I HAD A CHANCE TO STOP YOU RENEWING MY COVER
#
# Neutral,Positive,It does the job but the renewal costs are always way out, so I end up re-buying every time.
#
# Neutral,Positive,because you gave me no discount as a regular yearly renewal found much better deal from you on the internet higher protection and much cheaper, verydisappointed as regular subscriber no thought of any regular user discounts just top wack payment  TOTALLY disappointed you didnt offer me anything with discounts as a regular paid up customer at renewal shame on you
#
# Neutral,Positive,I have been with McAfee for a number of years now and have never had any problems as such with viruses, etc.   However I don't like getting messages from McAfee informing me that my subscription is due to finish and renew now to get a discount.   I renew automatically every year so should be getting the best price possible.
#
# Neutral,Negative,is a good program, but I've paid twice because I couldn't get in touch with anyone, because of the automatic payment, even when I wanted to get a discount that I heard about on the net.
#
# Neutral,Positive,I would have trouble recoommding because of cost and lack of customer service.  Hard to contact teck for help dwhen needed.  Know Mcphafee is under another company i am not sure we will renew let alone recommend them.
#
# Neutral,Negative,no support
#
# Neutral,Positive,McAfee was part of the package when i purchaxed my laptop.  I couldn't uninstall the program and when I tried I ended up having to buy it when I already owned another program
#
# Neutral,Negative,Your product is very effective, One thing is very disturbing, namely that Microsoft Defender just turned off your program and I now must deal under great time so, to install, although I was able to pay for it again. Please put pressure on Microsoft made to such actions refrain from. Your company is influential enough for this in my opinion.  MfG Christa Hlawinka
#
# Neutral,Negative,I have a problem with the version that I have and Windows 10. I frequently get an error that McAfee is not working and windows is starting Windows Defender. I also do not like the way that Quick clean works. I want to be able to retain some program accesses and Passwords without cleaning. I find your help process somewhat cumbersome and difficult.
#
# Neutral,Positive,Because I cannot use McAfee with Windows 10
#
# Neutral,Positive,Issues with windows 10
#
# Neutral,Negative,This product was provided as part of a package with a new mobile phone. Unfortunately it does not work with Windows 10 phone.
#
# Neutral,Positive,have alredy provided this info, it is also not compatable with my mobile phone.
#
# Neutral,Negative,It does not offer the protection that is promised. Many problems with software and incompatibility. Unfortunately and difficult to answer, I even gave up because whenever I looked for support the answer was that the problem was on my pc. Even with such super protection my pc was hacked. Money thrown out !!
#
# Neutral,Negative,last year had problems and a few hours on the phone with the helpdesk, and then was the problem is still not solved.
#
# Neutral,Negative,I nwas on the phone with them for over two hours while they helped with my problem.
#
# Neutral,Negative,I have experienced difficulty contacting a "real" person in order to discuss my contract with you! I believe I have two (2) separate contacts affording the same cover. I would wish to cancel one but have found this difficult!!
#
# Neutral,Positive,always trying to up-sell, and the basic programme does not fix the problems
#
# Neutral,Positive,Because you use English description too much for Japanese users.
#
# Neutral,Negative,McAfee works for me to your liking, all though it is not always clear for me what it does.
#
# Neutral,Negative,My email server goes thru aol and they keep sending me info on their internet security.
#
# Neutral,Positive,To date, it seem to work and is stable as an app. There are configuration aspects that either do not work or I can't figure out what they do or how to use them.
#
# Neutral,Negative,Although it does help with security, it tends to slow the procedure, which is annoying. I have a problem on my Acer laptop of storage, leadng to inability of adding programmes, so as such McAfee has not been installed.
#
# Neutral,Positive,Some time I do get span mail
#
# Neutral,Negative,Again, I am not always familiar with terms and operation of various features of the program.  I need information made simple.
#
# Neutral,Negative,Until this year we have always been with McAfee, but recently 2 salespersons from different computer stores have told us that McAfee have stagnated in virus control of late and been displaced by other progressives such as Norton?  We are not experts, so we have to be guided by other independent experts.
#
# Neutral,Negative,Because sometimes it is malfunctioning and slow down your pc
#
# Neutral,Negative,Very slow and unreliable product, virus, slow or long checks. Want it himself, if not will be more reliable and user-friendly.
#
# Neutral,Positive,I can't think of a time when I old recommend virus protection.  It also seems to have lots of error messages on my computer.
#
# Neutral,Negative,My computer locked up and I had to force the shutdown about 5 hours later and the screen still said that Mcafee was making updates.  I don't know whether these are done or not!
#
# Neutral,Negative,I can't get it to network my two computers and have to leave my firewall off in order to be able to access files
#
# Neutral,Negative,Live scan failed on my computer and would not restart even using your troubleshooting site. I had to do a system restore to get it to run.
#
# Neutral,Negative,McAfee failed to protect my computer from malware.
#
# Neutral,Negative,Operations less convenient. What archives are for example cannot be queried when the viral infection, only shows the empty "OOOOOO scan viruses" Also often shut down automatically (?)
#
# Neutral,Positive,Quite heavy, always restarts (App)
#
# Neutral,Positive,AS STATED EARLIER, I WOULD LIKE A MCAFEE TO BLOCK MICROSOFT FROM UPDATING MY COMPUTER.
#
# Neutral,Positive,its a little hard to navigate through the application and turn off or on settings, other then that the McAfee is a good product.
#
# Neutral,Positive,1. Numero Uno, I can not print on my network printer from McGetOurFee. It wants me to enter a password, auth. code or something from my printer! Do you see a fucking keyboard on my printer? Times in the past it actually worked. Every time your brilliant software engineers update, the printer stops working. I've been using a USB cable to print now for years. Unacceptable. 2. Dos. My goal was to cover ALL of my devices with McGetOurFee. Good Luck with that! I was intelligent enough not to install it on my mobile devices that use metered internet connections. I have enough trouble with Google Android. Why TF does everyone assume I have unlimited wireless bandwidth? All this crap NEVER updates when an unlimited DSL connection is available, only decides to do so at the worst possible moment: 2a: When I want to use a mobile device 2b1: Even this interface sucks. Mind of its own.  Have anyone there heard of standard API? 2b2: When the updates wait until the device is on a metered connection, even though an unlimited connection was previously available. Do all you have stock in Verizon? 3. Doesn't do doodly to prevent every BHO that wants to spend more time using my bandwidth than I do.  If we had a real U.S. Government, all those assholes would be lined up and shot.
#
# Neutral,Positive,At one stage, McAfee would not scan all the files on my computer, and google revealed this was due to a conscious decision by your company to only scan those files likely to have an infection.  It only scanned about 60,000 of about 420,000.  I contacted your company, who said the problem was probably at my end.  From this lie from your support people, I do not trust your company.  Full stop.  McAfee now scans all files, you probably changed it back due to backlash.
#
# Neutral,Negative,Too expensive for what I'm getting; hate that secure search has to change my search engine to Yahoo, so I turn it off; sometimes it's not the best at protecting my devices from viruses and malware; stuck with it for another year because of auto-renewal;
#
# Neutral,Positive,McAfee paid 3 months already and still not connected. already a letter written, but received no response
#
# Neutral,Positive,never was able to load on to phone , with no way to accept password
#
# Neutral,Positive,I had three calls to install McAfee Live Safe on two machines. The first Christian service was very good and the last one, with (USA) were quite satisfactory. However, the second service, with Sergio, was not good. The product is not installed and it looked like he didn't have sufficient expertise. The third service I needed because his clinic did not work. The product has been installed on the second machine in the third service, with Brabant
#
# Neutral,Positive,mit program virker ikke    efter 2 opkald til support   og en m�ned vente tid
#
# Neutral,Positive,Could not instal my purchased product
#
# Neutral,Positive,not impressed with product. Not easy to install or navigate
#
# Neutral,Negative,McAfee often does not seem to know which of devices it is supposed to be protecting.  Instead of staying exclusively with my tablet, it wants to download on my desktop which already has McAfee through my service provider. Very annoying!
#
# Neutral,Positive,You only got 9 because it is too difficult to change address, credit card info etc.  Any credit/debit card use in the online incurs a minor bank charge that is in-warranted and off-putting.
#
# Neutral,Positive,I fail to see any scanning reports, in fact nothing at all to indicate McAfee is doing anything other than collecting a fee from me.
#
# Neutral,Positive,You systematically renew 1 month before gives me the impression that you charge me all the 11 months. Moreover, in case of reinstallation on a PC that has been restored, the license management is complicated.
#
# Neutral,Negative,The product seems to be viable, but the marketing and predatory practices of McAfee are deceptive and inappropriate.
#
# Neutral,Positive,McAfee has always protected my computer and if the subject of computer protection came up, I would have no big problem recommending them. My big complaint is that I was not aware that McAfee came along free with my Bell package, and I have been paying for it individually.  How come McAfee could not see that I was already covered and still sent me renewals?  I realize this is something I should have picked up on earlier and it is somewhat my responsibility, but it would have been good customer service to let me know that I already had coverage.
#
# Neutral,Negative,I didn't want McAfee, but it came with something I downloaded (Adobe, maybe?) and now I can't stop getting these annoying emails...
#
# Neutral,Positive,Pricing
#
# Neutral,Positive,Increasingly, software slows down the system. Not Linux compatible. Non-transparent user interface. Little ways to customize. Not justified price.
#
# Neutral,Negative,Good product, slightly pricey.
#
# Neutral,Positive,Like I wrote before, there are lots of similar quaIity products for the cost.
#
# Neutral,Positive,Product too expensive!
#
# Neutral,Positive,Good usable program. Pricing is sometimes potentially deceptive - different price from e-mail. website or from within the program.
#
# Neutral,Positive,Very happy the product, apart I feel the price is too dear
#
# Neutral,Positive,Very Expensive
#
# Neutral,Positive,overpriced
#
# Neutral,Positive,Due to the increasing cost, as a new client it is lured with attractive offers. Once one is customer increase the annual amounts.
#
# Neutral,Positive,Have had no problems since installing McPhee, product is easy to use and not overly intrusive and ability to protect multiple devices I excellent. Cost would be prohibitive for some people I know when cheaper options are available.
#
# Neutral,Negative,cost and shortcomings in detecting and terminating some troublesome viruses.
#
# Neutral,Positive,I think it is very effective but very expensive
#
# Neutral,Positive,Too expensive, poor customer service.  Very difficult to get it to do a full scan.
#
# Neutral,Negative,price getting to expensive
#
# Neutral,Positive,Service is efficient but a little expensive
#
# Neutral,Negative,very good product suite, only prevented from a 10/10 by realtively high renewal prices...........
#
# Neutral,Positive,Subscription renewal messed up by mcafee and not competitive pricing. Still struggling to get it right
#
# Neutral,Negative,you charge to much, I am going to look into PCMATIC
#
# Neutral,Positive,Not 100% sold.  Pricey.  But at least it's not Kaspersky.   I mostly use my iPad.  It doesn't really help there, does it?
#
# Neutral,Positive,The price of the product is now very high. The scanning speed has become much slower.
#
# Neutral,Positive,Your security is good but has become expensive over recent years compared to other's , why don't you give a small discount to old customer's ?
#
# Neutral,Negative,Very happy, just unfortunately a bit expensive!
#
# Neutral,Positive,Expensive
#
# Neutral,Positive,I find that my PC is not enough protected for the price paid...
#
# Neutral,Positive,Not the cheapest, quite expensive compared to your competition and some packages for less expense do a lot more.
#
# Neutral,Negative,Because it is an expensive product and lately it has created me lots of problems. Earlier this year, I used a prepaid card in Prague in order to connect my computer to wifi via my smart phone hot spot. SInce then my computer connects to all sorts of unwanted websites and I keep receiving messages from McAfee saying that my computer is not protected enough. Isn't it the role of the McAfee software to protect my computer ? Lots of my friends use free anti virus software and never have this kind of problems.
#
# Neutral,Positive,It seems to expensive.
#
# Neutral,Positive,Good product but very expensive
#
# Neutral,Positive,The price of renewal is not consistent with best offers for purchases, it looks as a former customer, paying for a service that can be found cheaper elsewhere. This isn't what I call respect for the historic customer who makes you live long
#
# Neutral,Positive,McAfee is resource 'hog'.
#
# Neutral,Positive,sometimes it slows down my pc's
#
# Neutral,Negative,Security thru Verizon and direct slows down pc
#
# Neutral,Negative,Product is OK.  Computer still runs slower than expected at time and I wonder why/if related to things from internet.
#
# Neutral,Positive,Very good system, but it does slow my computer down slightly.
#
# Neutral,Positive,drains too many resources
#
# Neutral,Positive,I have had to turn off your soft ware as when I took my computer repeatedly for repair due to it "crashing" or going so very slow, the fault was your programme, it has been working without problem since.
#
# Neutral,Positive,Requires and consumes lot of resources. True key saves passwords even I don't want it (for sensitive accounts)
#
# Neutral,Negative,I have difficulty because she made my machine more slowly
#
# Neutral,Positive,Although it seems very efficient and effective at identifying and weeding out viruses and other malware, it definitely does not run in the background! It takes so much of all my laptop's resources to do its job that I'm left with a very slow and frustrating machine. The most annoying thing is that I am unable to disable McAfee when I need the best performance from my laptop. I turn 'real time scanning' off, until further notice, and it just turns itself on  again. So, the next time I boot up my machine it takes 10 minutes plus, when it should take 2 or 3. I have years of experience with all sorts of computers  and I do know how to regulate the programs that are running at start-up and whilst I'm using the laptop and I know that McAfee is far too memory-hungry. I need to be able to disable it fully (particularly when I am not accessing the internet) unless I need it to be running.
#
# Neutral,Positive,mcafee has slowed my computer down and some time won't allow me to use it until it finishes what is it doing
#
# Neutral,Negative,It seems to use a lot of machine resources and causes delays.
#
# Neutral,Negative,Why does my computer to work very slowly. As antivirus is good but not for any machine.
#
# Neutral,Positive,Computer performance may decrease slightly frustrated because it is no better.
#
# Neutral,Positive,too heavy program esp. for older machines
#
# Neutral,Negative,I have a large McAfee advert which opens every time I start my laptop, telling me how marvellous you are, slowing the computer down massively
#
# Neutral,Positive,My IE hangs very regularly and it's probably because of a tussle between IE and McAfee. The problem is it just hangs without any info. as to what the problem is and the only solution thereafter is to force close the IE through the Task Manager
#
# Neutral,Negative,because even with McAfee active I found myself with the internet almost useless for the continuous reindirizzamentoa objects not required. So I had to upload another antivirus that has found an enormity of malware around 1600 malicious objects that your antivirus hasn't even noticed!
#
# Neutral,Positive,Used to have McAfee sense but currently carries the nothing more to my protection. It only slows down the machine.
#
# Neutral,Positive,Because the only time my desktop ever had an internet virus in the 12 years I have had it was when I had MacAffee. The free options work much better for me.
#
# Neutral,Positive,I cant observe the online banking protection but except that everything is good
#
# Neutral,Positive,My personal laptop had 65 viruses on it!  It was a 2 year old Dell - now its garbage.  All the while running a current McAfee subscription.  Had to purchase a new MAC book & will use Apple security.  I want a refund for my subscription which is now useless & doesn't expire until July.
#
# Neutral,Negative,My computer still gets things (malware) that you couldn't find.
#
# Neutral,Positive,I got several viruses on my pc while using McAfee
#
# Neutral,Positive,because my computer keep getting viruses.
#
# Neutral,Positive,I have 4 computers but only 1 is on the internet.  A while back, the others were wiped out by a virus.  All three had up to date McAfee !  They also use McAfee at work ( 30,000 Employees ).  We are constantly having problems.
#
# Neutral,Positive,Because it. Did not keep 2 bad viruses out of my computer. I am not using McAffee currently because of that.
#
# Neutral,Positive,Because I've had viruses on the computer, even with the software
#
# Neutral,Positive,Like, use webroot
#
# Neutral,Positive,disappointed in your malware functionality. (is there any?)  Malware Bytes(free) finds infections that this paid product does not.  The firewall does not put the pc into stealth mode.  (443, and others appear open)  test at www.grc.com use their port scanner
#
# Neutral,Negative,As my computer was hacked & malicious material sent to friends on facebook
#
# Neutral,Positive,My computer has been down for over 6 months due to a virus that infected it and I don't presently have the funds to fix it
#
# Neutral,Positive,My computer has been attacked by viruses
#
# Neutral,Positive,The product is great and gives great protection.  My only issues are that is really slows down the pc when running a full scan and takes up a lot of memory.
#
# Neutral,Positive,Have had McAfee for years.  May 2017 had issues with inability to remove cookies, shredder, etc.  Staff remotely deinstalled & reinstalled new program.  Worked for a couple of times, still unable to shred, remove cookies, tracking.  Then "windows doesn't update & cannot complete updates".  Was directed to support but there's a large cost.
#
# Neutral,Positive,Just had my computer in for service, they tell me I had 92 viruses.
#
# Neutral,Positive,Historically, I have found that the program fails to offer meaningful protection.  In addition, it is intrusive in many areas where I don't want it to be. And it is expensive.
#
# Neutral,Positive,because you keep blocking emails that we want
#
# Neutral,Positive,Because it doesn't always protect my system.
#
# Neutral,Negative,There have been several undetected viruses and yes were by other antivirus
#
# Neutral,Negative,Because I never asked for it to be renewed and was never told you were going to just going to take my money. I have asked for my money back but have received no reply
#
# Neutral,Positive,Reliability of security Price,
#
# Neutral,Positive,I already wrote earlier. I would add that the safety net is a function unstable that does not remember the settings, I often tap reset. Mc Afee is a product that requires constant manutenzionone and misses the minacche that other security systems that I have installed are blocking in real time. Call it "TOTAL PROTECTION" is misleading and flaso.
#
# Neutral,Positive,Because of having been cheated upon renewal of subscription!!!
#
# Neutral,Positive,The renewal options are difficult and the automated feature makes it hard to change to a different type of package.
#
# Neutral,Positive,I have Mcafee  cover and I keep getting notifications saying my computer is at risk give us more money. When this subscription ends i will find another company
#
# Neutral,Positive,Too many and too early warnings about coverage running out.
#
# Neutral,Negative,Protection is good, but renewal notices are confusing. I got emails with a a link to a website that gave different info than the link I found in the tool on my computer. I STILL get annoying  warnings that my subscription has expired even tho I reordered. How do I stop these?
#
# Neutral,Negative,only 5 because of the constant popping of the sign " your mac Afee  subscription has expired " even when it has just been renewed
#
# Neutral,Positive,i have to call or chat online to get my laptop scanned when anything goes wrong. I'm told it's "not a McAfee problem" and blown off without resolution.
#
# Neutral,Positive,Your customer service reps have always been very helpful in resolving any problems I have had.
#
# Neutral,Negative,because in the end my problem was solved but it took longer than i beleive it should
#
# Neutral,Positive,The virus protection system works very well, when it is working.  The service provided necessary to fix problems preventing proper system operation has never been up to my expectations.  This time, at least your service techs did follow up with me to ensure the problem was resolved but it took almost a month to resolve the problem.
#
# Neutral,Positive,Service Request Number: 484570- 2305839277 then read what I said earlier.  Have been with McAfee over 20 yrs and then it hits a brick wall.  Everyone is very sorry about my problem and McAfee is working on a fix and will be in touch.  Repeated emails advising McAfee are still working on it and will be in touch doesn't do much for me. Total lack of customer service as far as I'm concerned.  So disappointing after so many good years.  Does anyone in  management know of my problem or is it being suppressed at a level to avoid anyone getting a kick in the backside because it still hasn't been fixed after 4 months?
#
# Neutral,Negative,Customer service is lacking/woefully slow to response to messages
#
# Neutral,Negative,good but been a few problems needing contact with you
#
# Neutral,Positive,Poor product
#
# Neutral,Negative,Each scan segar down your PC so it becomes almost unusable. Since I don't use my computer daily so begins the search almost every time I turn it on.
#
# Neutral,Positive,It's rubbish, and the hilarious thing is that whenever I tried to get answers to questions, the McAfee chat site was apparently unsafe and could potentially harm my device. How ironic.
#
# Neutral,Positive,You never really know if the software is downloaded and working
#
# Neutral,Negative,Lack of support
#
# Neutral,Positive,The product is good but too complicated web site and support payment incomode (English)
#
# Neutral,Positive,Your software provides me with error messages all the time.  Your software does not know that I pay for services every year.  You cannot get any assistance even though I have purchased software yearly for what 10 years?
#
# Neutral,Positive,Doesn't work!
#
# Neutral,Positive,There does not seem to be any element of the product that distinguishes it from the competition.
#
# Neutral,Negative,Because it does not work well or efficiently
#
# Neutral,Negative,Because my PC for months sent spam and I can't make a call to a service provider I pay
#
# Neutral,Positive,wish to unsubscribe but seem unable to do so.also product does not seem to work.only to debit my card account
#
# Neutral,Negative,I have other protection yet you keep pestering me with ads and messages.
#
# Neutral,Negative,because I am missing notices when there are world events like ramsonwhere or maybe they sent it and I could not see it. Otherwise not be as do a disk or a bootable pendrive to clean other computers using my family also. I have this possibility
#
# Neutral,Positive,This product does not fully understand the
#
# Neutral,Positive,Found it no better or worse than other products on the market
#
# Neutral,Negative,given my bad experience with McAfee
#
# Neutral,Positive,to expensive.  I only want to protect one device
#
# Neutral,Positive,Poor business practices.  I had a subscription that came with my HP Envy.  I had a second subscription when I purchased a new Dell.  I was assured by one of your specialists that the "clock" on that one wouldn't start until the HP subscription expired. Now I find out that my service has expired.  Since one subscription will cover all my devices, there was no need to run both subscriptions simultaneously.  I was told one thing when I called and then find that  information was incorrect.  It appears to me to be a ploy to purchase a licence a year sooner than I would have.
#
# Neutral,Positive,no efficiency
#
# Neutral,Positive,Because I have found it too difficult to cancel my subscription - I have been trying for 2 years!!!  Telling someone to 'look at their account' is not helpful if that person doesn't know how to access it!
#
# Neutral,Positive,It's good but sometimes I get some bad emails through.
#
# Neutral,Positive,By the previously mentioned. Despite having it installed, on one occasion I could detect a virus not repair a USB which I introduced on another computer and I lost my files. The virus made a conversion of my files to 1 kb shortcuts and now I could not recover them.
#
# Neutral,Negative,We have had an ongoing problem with the subscription confusing devices, there needs to be an easier way to see what devices are covered by our subscription
#
# Neutral,Positive,I was charged for a renewal without my approval. The reminders to renew are good. But if I don't renew the virusscan...it's up to me to click on the link or contact McAfee to renew it. You should never renew it and charge it from somebodies credit card.
#
# Neutral,Positive,Actually the Microsoft Defender offers sufficient protection.
#
# Neutral,Positive,There may be better products out there.
#
# Neutral,Positive,Product meets but has no differentials in relation to competitors.
#
# Neutral,Positive,I don't understand billing, don't know which computers are protected and confused about whit I get for the cost
#
# Neutral,Negative,I have stated that I do not want to make more use of ma. Afee. I have another computer. I have emailed twice and something of your heard. This find I resent.
#
# Neutral,Negative,I had problems renewing and from time to time the service went offline.  I have no complaints about McAfee protection.
#
# Neutral,Negative,Does not appear in the phone does something. It is my simple perception, but it seems that is to occupy space.
#
# Neutral,Positive,problems too difficult to solve via the website
#
# Neutral,Positive,Because when I agreed to LIVESAFE, McAfee did NOT tell me that I didn't need the other product I have installed on the other computer... could had saved me a lot of money.
#
# Neutral,Positive,I have been using Mcafee for years, I am very unhappy with the latest edition of Total Protection.
#
# Neutral,Positive,see first question. in addition I do not like the proactive marketing, wanting me to buy more / other products of Mcafee
#
# Neutral,Positive,because i have some problems with your product
#
# Neutral,Positive,Overkill
#
# Neutral,Positive,poor accessibility and information on website m.b.t. problems not usable
#
# Neutral,Negative,not sure about the quality of the product, do not look for new updates happening,, doesn't seem to be the new "viral object.". Has been in contact with your customer service but they recommended me to just re-install the product. no major support at that time. Unfortunately..
#
# Neutral,Negative,Lately I have had to uninstall and then reinstall because it says it is downloading updates that never seem to get finished
#
# Neutral,Positive,seems to be working ok but you are just not sure it is need to updated of seem sort while you are on the net to know you are save
#
# Neutral,Positive,Aside from some issues during updates, McAfee works as promised.
#
# Neutral,Positive,Interface is not as easy to use as previous versions. To many warnings, even after changing settings if you can find them.
#
# Neutral,Positive,Seems ok but interface not as user friendly as Norton.
#
# Neutral,Negative,Dont really understand it anyway.
#
# Neutral,Positive,product is good as i haven't had an issues, so i don't want to take away from that, but recommending a security product is risky and i prefer not to do that as i don't know what the future holds for mcafee. i put the product on my mother's computer (old person) and she is having a hard time with it, and i believe she has a virus that will not allow her to update or repair the issue.  and the mcafee program will not fix the problem.
#
# Neutral,Positive,I have not found McAfee to be very user friendly, particularly, when it comes time to renew my subscription.  Instead of giving me an advance warning that the subscription is about to renew so that I can exercise an informed choice, it notifies me after the fact that my subscription has renewed and the cost of the renewal has already been deducted from my account.  I consider that to be sneaky, not necessarily a feature I look for in a software app.
#
# Neutral,Positive,It's very confusing find out where particular configuration to change it
#
# Neutral,Positive,Price/performance? There are now offers of Ziggo where "free" F-Secure for multiple platforms is offered. in terms of performance and performance this seems also a good product
#
# Neutral,Positive,am a fanatic fan but there's always room for improvements
#
# Neutral,Positive,Because that what I felt was appropriate!
#
# Neutral,Positive,So so
#
# Neutral,Positive,It is difficult to recommend a product, so I prefer to make a reservation.
#
# Neutral,Negative,Don't know what others are like.
#
# Neutral,Positive,Not a subject I would normally discuss
#
# Neutral,Positive,from my feeling out
#
# Neutral,Negative,I understand very little of all this so could not recommend it to anyone
#
# Neutral,Negative,because there are other options.
#
# Neutral,Positive,Technically good financial unclear by various subscriptions.
#
# Neutral,Positive,I have no settled opinion
#
# Neutral,Negative,.
#
# Neutral,Negative,T

# %%
from sklearn.externals import joblib
joblib.dump(clf_adaboost, "1.0adaboost.pk1")
# Out:
# ['1.0adaboost.pk1']

# %%
#loaded_one = joblib.load("0.82_lsvc.pk1")
#loaded_one.predict(asdasdasdasdasd)

# %%
def clear_input(list_string):
    cleared_token = {}
    for i in xrange(len(list_string)):
        comment = list_string[i]
        comment = comment.lower() # lower case
        comment = lowers.translate(None, string.punctuation) # remove puncu
        comment = unicode(comment, errors='replace')
        cleared_token[i] = comment
    
    tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(1,1))
    tfs = tfidf.fit_transform(cleared_token.values())
    
    df = pd.DataFrame(data=tfs.toarray(), 
                  index = cleared_token.keys(), 
                  columns=tfidf.get_feature_names())
    print "customize input: ", df
    
    df = df.as_matrix()
    return df
print "old one", df
answer = clear_input(["i have no idea this can work"])
clf_lsvc.predict([X_train[0]])
